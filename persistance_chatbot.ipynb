# %%
import os
os.environ["LANGGRAPH_DISABLE_DAG_RENDER"] = "1"
from langgraph.graph import StateGraph, START, END
from typing import TypedDict, Annotated
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from google import genai
from langgraph.checkpoint.memory import MemorySaver, InMemorySaver
from langchain_core.messages import BaseMessage, HumanMessage
from langgraph.graph.message import add_messages

# %%
load_dotenv()
# Out:
# True

# %%
import os
api_key = os.getenv("GEMINI_API_KEY2") # or os.getenv("GEMINI_API_KEY")
if not api_key:
	raise EnvironmentError("GEMINI_API_KEY2 (or GEMINI_API_KEY) not set in environment. Add it to your .env or export it.")

# client = genai.Client(api_key=api_key)

# %%
model = ChatOpenAI(
   model="gemini-2.5-flash",
   api_key=api_key,
   base_url="https://generativelanguage.googleapis.com/v1beta/openai"
)

# %%
class JokeState(TypedDict):
    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):
    topic= state['topic']
    prompt= f'write humorous joke on following topic: {topic}'
    response= model.invoke(prompt).content
    return {"joke": response}

# %%
def explain_joke(state: JokeState):
    joke= state['joke']
    prompt= f'Explain the following joke: \n {joke}'
    resp= model.invoke(prompt).content
    return {'explanation': resp}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('get_explanation', explain_joke)

graph.add_edge(START, 'generate_joke')
graph.add_edge("generate_joke", 'get_explanation')
graph.add_edge("get_explanation", END)

checkpointer= InMemorySaver()

joke_and_explain= graph.compile(checkpointer=checkpointer)

# %%
config1= {'configurable': {"thread_id": "1"}}

# %%
initial_state= {"topic": "Politics"}
final_state= joke_and_explain.invoke(initial_state, config= config1)

# %%
print(final_state['joke'])
# Out:
# Here are a few humorous jokes about politics:
#
# 1.  "How do you know when a politician is lying?"
#     "Their lips are moving."
#
# 2.  "What's the difference between a politician and a baby?"
#     "Eventually, you can reason with the baby."
#
# 3.  A politician, a lawyer, and an honest man walk into a bar.
#     The bartender looks up and says, "Hey, an honest man! What can I get you?"
#
# 4.  "Why do politicians always talk about the future?"
#     "Because it's easier to promise things that way."
#
# 5.  Politics is like a treadmill. You exert a lot of energy, feel like you're going somewhere, but ultimately end up in the same place.

# %%
print(final_state['explanation'])
# Out:
# These jokes all play on common stereotypes and cynical perceptions about politicians and the political process. They derive their humor from exaggeration, unexpected comparisons, and biting social commentary.
#
# Let's break them down:
#
# 1.  **"How do you know when a politician is lying?" "Their lips are moving."**
#     *   **Explanation:** This is a classic piece of hyperbole. It humorously exaggerates the widespread perception that politicians are inherently dishonest and lie constantly. The joke implies that anything a politician says is likely a lie, simply by virtue of them speaking.
#
# 2.  **"What's the difference between a politician and a baby?" "Eventually, you can reason with the baby."**
#     *   **Explanation:** This joke uses an unflattering comparison. It suggests that politicians, despite being adults, are unreasonable, stubborn, and impervious to logic, facts, or the concerns of the public. A baby, though initially irrational, will eventually develop the capacity for reason, implying politicians *never* will.
#
# 3.  **A politician, a lawyer, and an honest man walk into a bar. The bartender looks up and says, "Hey, an honest man! What can I get you?"**
#     *   **Explanation:** This joke plays on negative stereotypes associated with both politicians and lawyers, who are often perceived as dishonest or manipulative. The humor comes from the bartender's surprise and immediate attention to the "honest man," implying that the politician and lawyer are, by default, *not* honest, making the "honest man" a rare and noteworthy presence in that company.
#
# 4.  **"Why do politicians always talk about the future?" "Because it's easier to promise things that way."**
#     *   **Explanation:** This joke critiques a common political tactic. Politicians often make grand promises during campaigns or speeches about what they *will* do in the future. The humor lies in the cynical implication that these promises are often empty or impossible to fulfill, but by placing them in the future, politicians are less accountable for their immediate delivery. It suggests they use "the future" as a safe space for making pledges without immediate repercussions.
#
# 5.  **Politics is like a treadmill. You exert a lot of energy, feel like you're going somewhere, but ultimately end up in the same place.**
#     *   **Explanation:** This is an analogy that expresses frustration and a sense of futility with the political process. The "exert a lot of energy" refers to all the campaigning, debates, policy changes, and public discourse. "Feel like you're going somewhere" captures the hope and belief in progress. "Ultimately end up in the same place" is the punchline, suggesting that despite all the effort and changes, fundamental problems persist, society doesn't truly advance, or things revert to an earlier state, leaving people feeling stagnant.
#
# In essence, all these jokes tap into a widespread public sentiment of distrust, disillusionment, and cynicism towards politicians and the effectiveness of the political system.

# %%
joke_and_explain.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'Politics', 'joke': 'Here are a few humorous jokes about politics:\n\n1.  "How do you know when a politician is lying?"\n    "Their lips are moving."\n\n2.  "What\'s the difference between a politician and a baby?"\n    "Eventually, you can reason with the baby."\n\n3.  A politician, a lawyer, and an honest man walk into a bar.\n    The bartender looks up and says, "Hey, an honest man! What can I get you?"\n\n4.  "Why do politicians always talk about the future?"\n    "Because it\'s easier to promise things that way."\n\n5.  Politics is like a treadmill. You exert a lot of energy, feel like you\'re going somewhere, but ultimately end up in the same place.', 'explanation': 'These jokes all play on common stereotypes and cynical perceptions about politicians and the political process. They derive their humor from exaggeration, unexpected comparisons, and biting social commentary.\n\nLet\'s break them down:\n\n1.  **"How do you know when a politician is lying?" "Their lips are moving."**\n    *   **Explanation:** This is a classic piece of hyperbole. It humorously exaggerates the widespread perception that politicians are inherently dishonest and lie constantly. The joke implies that anything a politician says is likely a lie, simply by virtue of them speaking.\n\n2.  **"What\'s the difference between a politician and a baby?" "Eventually, you can reason with the baby."**\n    *   **Explanation:** This joke uses an unflattering comparison. It suggests that politicians, despite being adults, are unreasonable, stubborn, and impervious to logic, facts, or the concerns of the public. A baby, though initially irrational, will eventually develop the capacity for reason, implying politicians *never* will.\n\n3.  **A politician, a lawyer, and an honest man walk into a bar. The bartender looks up and says, "Hey, an honest man! What can I get you?"**\n    *   **Explanation:** This joke plays on negative stereotypes associated with both politicians and lawyers, who are often perceived as dishonest or manipulative. The humor comes from the bartender\'s surprise and immediate attention to the "honest man," implying that the politician and lawyer are, by default, *not* honest, making the "honest man" a rare and noteworthy presence in that company.\n\n4.  **"Why do politicians always talk about the future?" "Because it\'s easier to promise things that way."**\n    *   **Explanation:** This joke critiques a common political tactic. Politicians often make grand promises during campaigns or speeches about what they *will* do in the future. The humor lies in the cynical implication that these promises are often empty or impossible to fulfill, but by placing them in the future, politicians are less accountable for their immediate delivery. It suggests they use "the future" as a safe space for making pledges without immediate repercussions.\n\n5.  **Politics is like a treadmill. You exert a lot of energy, feel like you\'re going somewhere, but ultimately end up in the same place.**\n    *   **Explanation:** This is an analogy that expresses frustration and a sense of futility with the political process. The "exert a lot of energy" refers to all the campaigning, debates, policy changes, and public discourse. "Feel like you\'re going somewhere" captures the hope and belief in progress. "Ultimately end up in the same place" is the punchline, suggesting that despite all the effort and changes, fundamental problems persist, society doesn\'t truly advance, or things revert to an earlier state, leaving people feeling stagnant.\n\nIn essence, all these jokes tap into a widespread public sentiment of distrust, disillusionment, and cynicism towards politicians and the effectiveness of the political system.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c52d7-057a-6a00-8002-06527ffa3a7d'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-11-19T09:52:19.74789 ...

# %%
list(joke_and_explain.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'Politics', 'joke': 'Here are a few humorous jokes about politics:\n\n1.  "How do you know when a politician is lying?"\n    "Their lips are moving."\n\n2.  "What\'s the difference between a politician and a baby?"\n    "Eventually, you can reason with the baby."\n\n3.  A politician, a lawyer, and an honest man walk into a bar.\n    The bartender looks up and says, "Hey, an honest man! What can I get you?"\n\n4.  "Why do politicians always talk about the future?"\n    "Because it\'s easier to promise things that way."\n\n5.  Politics is like a treadmill. You exert a lot of energy, feel like you\'re going somewhere, but ultimately end up in the same place.', 'explanation': 'These jokes all play on common stereotypes and cynical perceptions about politicians and the political process. They derive their humor from exaggeration, unexpected comparisons, and biting social commentary.\n\nLet\'s break them down:\n\n1.  **"How do you know when a politician is lying?" "Their lips are moving."**\n    *   **Explanation:** This is a classic piece of hyperbole. It humorously exaggerates the widespread perception that politicians are inherently dishonest and lie constantly. The joke implies that anything a politician says is likely a lie, simply by virtue of them speaking.\n\n2.  **"What\'s the difference between a politician and a baby?" "Eventually, you can reason with the baby."**\n    *   **Explanation:** This joke uses an unflattering comparison. It suggests that politicians, despite being adults, are unreasonable, stubborn, and impervious to logic, facts, or the concerns of the public. A baby, though initially irrational, will eventually develop the capacity for reason, implying politicians *never* will.\n\n3.  **A politician, a lawyer, and an honest man walk into a bar. The bartender looks up and says, "Hey, an honest man! What can I get you?"**\n    *   **Explanation:** This joke plays on negative stereotypes associated with both politicians and lawyers, who are often perceived as dishonest or manipulative. The humor comes from the bartender\'s surprise and immediate attention to the "honest man," implying that the politician and lawyer are, by default, *not* honest, making the "honest man" a rare and noteworthy presence in that company.\n\n4.  **"Why do politicians always talk about the future?" "Because it\'s easier to promise things that way."**\n    *   **Explanation:** This joke critiques a common political tactic. Politicians often make grand promises during campaigns or speeches about what they *will* do in the future. The humor lies in the cynical implication that these promises are often empty or impossible to fulfill, but by placing them in the future, politicians are less accountable for their immediate delivery. It suggests they use "the future" as a safe space for making pledges without immediate repercussions.\n\n5.  **Politics is like a treadmill. You exert a lot of energy, feel like you\'re going somewhere, but ultimately end up in the same place.**\n    *   **Explanation:** This is an analogy that expresses frustration and a sense of futility with the political process. The "exert a lot of energy" refers to all the campaigning, debates, policy changes, and public discourse. "Feel like you\'re going somewhere" captures the hope and belief in progress. "Ultimately end up in the same place" is the punchline, suggesting that despite all the effort and changes, fundamental problems persist, society doesn\'t truly advance, or things revert to an earlier state, leaving people feeling stagnant.\n\nIn essence, all these jokes tap into a widespread public sentiment of distrust, disillusionment, and cynicism towards politicians and the effectiveness of the political system.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c52d7-057a-6a00-8002-06527ffa3a7d'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-11-19T09:52:19.7478 ...
#  StateSnapshot(values={'topic': 'Politics', 'joke': 'Here are a few humorous jokes about politics:\n\n1.  "How do you know when a politician is lying?"\n    "Their lips are moving."\n\n2.  "What\'s the difference between a politician and a baby?"\n    "Eventually, you can reason with the baby."\n\n3.  A politician, a lawyer, and an honest man walk into a bar.\n    The bartender looks up and says, "Hey, an honest man! What can I get you?"\n\n4.  "Why do politicians always talk about the future?"\n    "Because it\'s easier to promise things that way."\n\n5.  Politics is like a treadmill. You exert a lot of energy, feel like you\'re going somewhere, but ultimately end up in the same place.'}, next=('get_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c52d6-a043-6bd4-8001-320105573e98'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-11-19T09:52:09.134792+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c52d6-0be9-6ac9-8000-c9f41cbf0a06'}}, tasks=(PregelTask(id='c335a71c-df8d-a8f3-8c80-03269397df29', name='get_explanation', path=('__pregel_pull', 'get_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'These jokes all play on common stereotypes and cynical perceptions about politicians and the political process. They derive their humor from exaggeration, unexpected comparisons, and biting social commentary.\n\nLet\'s break them down:\n\n1.  **"How do you know when a politician is lying?" "Their lips are moving."**\n    *   **Explanation:** This is a classic piece of hyperbole. It humorously exaggerates the widespread perception that politicians are inherently dishonest and lie constantly. The joke implies that anything a politician says is likely a lie, simply by virtue of them speaking.\n\n2.  **"What\'s the difference between a politician and a baby?" "Eventually, you can reason with the baby."**\n    *   **Explanation:** This joke uses an unflattering comparison. It suggests that politicians, despite being adults, are unreasonable, stubborn, and impervious to logic, facts, or the concerns of the public. A baby, though initially irrational, will eventually develop the capacity for reason, implying politicians *never* will.\n\n3.  **A politician, a lawyer, and an honest man walk into a bar. The bartender looks up and says, "Hey, an honest man! What can I get you?"**\n    *   **Explanation:** This joke plays on negative stereotypes associated with both politicians and lawyers, who are often perceived as dishonest or manipulative. The humor comes from the bartender\'s surprise and immediate attention to the "honest man," implying that the politician and lawyer are, by default, *not* honest, making the "honest man" a rare and noteworthy presence in that company.\n\n4.  **"Why do politicians always talk about the future?" "Because it\'s easier to promise things that way."**\n    *   **Explanation:** This joke critiques a common political tactic. Politicians often make grand promises during campaigns or speeches about what they *will* do in the future. The humor lies in the cynical implication that these promises are often empty or impossible to fulfill, but by placing them in the future, politicians are less accountable for their immediate delivery. It suggests they use "the future" as a safe space for making pledges without immediate repercussions.\n\n5.  **Politics is like a treadmill. You exert a lot of energy, feel like you\'re going somewhere, but ultimately end up in the same place.**\n    *   **Explanation:** This is an analogy that expresses frustration and a sense of futility with the political process. The "exert a lot of energy" refers to all the campaigning, debates, policy changes, and public discourse. "Feel like you\'re going somewhere" captures the hope and belief in progress. "Ultimately end up in the same place" is the punchline, suggesting that despite all the e ...
#  StateSnapshot(values={'topic': 'Politics'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c52d6-0be9-6ac9-8000-c9f41cbf0a06'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-11-19T09:51:53.578976+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c52d6-0be2-65a9-bfff-deec2d53ce33'}}, tasks=(PregelTask(id='09751f75-db01-17b8-ecc2-07776a096c92', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Here are a few humorous jokes about politics:\n\n1.  "How do you know when a politician is lying?"\n    "Their lips are moving."\n\n2.  "What\'s the difference between a politician and a baby?"\n    "Eventually, you can reason with the baby."\n\n3.  A politician, a lawyer, and an honest man walk into a bar.\n    The bartender looks up and says, "Hey, an honest man! What can I get you?"\n\n4.  "Why do politicians always talk about the future?"\n    "Because it\'s easier to promise things that way."\n\n5.  Politics is like a treadmill. You exert a lot of energy, feel like you\'re going somewhere, but ultimately end up in the same place.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c52d6-0be2-65a9-bfff-deec2d53ce33'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-11-19T09:51:53.575978+00:00', parent_config=None, tasks=(PregelTask(id='e681a940-e73a-6cff-514c-475a59d027f5', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'Politics'}),), interrupts=())]

# %%
config2= {'configurable': {"thread_id": "2"}}
initial_state= {"topic": "Bollywood"}
final_state2= joke_and_explain.invoke(initial_state, config= config2)

# %%
list(joke_and_explain.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'Bollywood', 'joke': 'Why did the Bollywood actor bring a map of Switzerland to a family dinner?\n\nJust in case a dramatic revelation led to a spontaneous song and dance sequence!', 'explanation': 'This joke plays on several classic Bollywood tropes:\n\n1.  **Dramatic Revelations at Family Events:** Bollywood films are famous for their high drama, often involving long-lost relatives, secret love affairs, hidden parentage, or other major family secrets that come to light, usually with shouting, tears, and grand gestures. A family dinner is a perfect setting for such a "dramatic revelation."\n\n2.  **Spontaneous Song and Dance Sequences:** This is the absolute hallmark of Bollywood cinema. Characters frequently break into elaborate song and dance numbers, seemingly out of nowhere, to express intense emotions, advance the plot, or simply provide a colorful interlude. These sequences are often triggered by a significant emotional event – like a "dramatic revelation."\n\n3.  **Exotic Filming Locations for Song Sequences:** Many Bollywood song sequences are shot in breathtaking, picturesque international locations, even if the rest of the film is set in India. **Switzerland** is one of the *most famous and beloved* international backdrops for Bollywood song and dance numbers. Its snowy mountains, lush green fields, and charming villages have appeared in countless Hindi films, becoming almost synonymous with romantic song sequences.\n\n**Putting it all together:**\n\nThe joke imagines a Bollywood actor, so immersed in the conventions of his craft, that he anticipates a typical cinematic event happening in real life. He\'s thinking:\n\n*   "Oh no, a family dinner! This is where secrets usually explode!" (Dramatic revelation)\n*   "And when secrets explode, emotions run high, which means... it\'s time for a song and dance!" (Spontaneous song and dance)\n*   "And where do the best, most beautiful song and dance sequences happen? In Switzerland, of course!"\n\nSo, the actor brings a map of Switzerland, "just in case" the dramatic family revelation leads to an immediate need for a picturesque backdrop for an impromptu musical number, à la a typical Bollywood movie. The humor comes from the absurdity of applying these hyper-stylized cinematic conventions to a real-life, mundane family dinner.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c537a-6533-660e-8002-d7aeef8d1ff8'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-11-19T11:05:25.282971+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c537a-1157-6174-8001-b9d6a8373253'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'Bollywood', 'joke': 'Why did the Bollywood actor bring a map of Switzerland to a family dinner?\n\nJust in case a dramatic revelation led to a spontaneous song and dance sequence!'}, next=('get_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c537a-1157-6174-8001-b9d6a8373253'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-11-19T11:05:16.489560+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c5379-a49f-6b12-8000-54b788793a5a'}}, tasks=(PregelTask(id='15509699-129a-60c0-84fd-e9d567725421', name='get_explanation', path=('__pregel_pull', 'get_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke plays on several classic Bollywood tropes:\n\n1.  **Dramatic Revelations at Family Events:** Bollywood films are famous for their high drama, often involving long-lost relatives, secret love affairs, hidden parentage, or other major family secrets that come to light, usually with shouting, tears, and grand gestures. A family dinner is a perfect setting for such a "dramatic revelation."\n\n2.  **Spontaneous Song and Dance Sequences:** This is the absolute hallmark of Bollywood cinema. Characters frequently break into elaborate song and dance numbers, seemingly out of nowhere, to express intense emotions, advance the plot, or simply provide a colorful interlude. These sequences are often triggered by a significant emotional event – like a "dramatic revelation."\n\n3.  **Exotic Filming Locations for Song Sequences:** Many Bollywood song sequences are shot in breathtaking, picturesque international locations, even if the rest of the film is set in India. **Switzerland** is one of the *most famous and beloved* international backdrops for Bollywood song and dance numbers. Its snowy mountains, lush green fields, and charming villages have appeared in countless Hindi films, becoming almost synonymous with romantic song sequences.\n\n**Putting it all together:**\n\nThe joke imagines a Bollywood actor, so immersed in the conventions of his craft, that he anticipates a typical cinematic event happening in real life. He\'s thinking:\n\n*   "Oh no, a family dinner! This is where secrets usually explode!" (Dramatic revelation)\n*   "And when secrets explode, emotions run high, which means... it\'s time for a song and dance!" (Spontaneous song and dance)\n*   "And where do the best, most beautiful song and dance sequences happen? In Switzerland, of course!"\n\nSo, the actor brings a map of Switzerland, "just in case" the dramatic family revelation leads to an immediate need for a picturesque backdrop for an impromptu musical number, à la a typical Bollywood movie. The humor comes from the absurdity of applying these hyper-stylized cinematic conventions to a real-life, mundane family dinner.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'Bollywood'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c5379-a49f-6b12-8000-54b788793a5a'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-11-19T11:05:05.089819+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c5379-a49d-639e-bfff-6fd0d67c60ac'}}, tasks=(PregelTask(id='e9897d55-3d35-2af5-1ec9-c29b73f15d59', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the Bollywood actor bring a map of Switzerland to a family dinner?\n\nJust in case a dramatic revelation led to a spontaneous song and dance sequence!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c5379-a49d-639e-bfff-6fd0d67c60ac'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-11-19T11:05:05.088809+00:00', parent_config=None, tasks=(PregelTask(id='99fab488-acac-f1be-4093-e6bae600717d', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'Bollywood'}),), interrupts=())]

# %% [markdown]
# ### Time Traveling

# %%
config2_timeTravel= {'configurable': {"thread_id": "2", "checkpoint_id":"1f0c537a-1157-6174-8001-b9d6a8373253"}}

# %%
joke_and_explain.invoke(None, {'configurable': {"thread_id": "2", "checkpoint_id":"1f0c537a-1157-6174-8001-b9d6a8373253"}})
# Out:
# {'topic': 'Bollywood',
#  'joke': 'Why did the Bollywood actor bring a map of Switzerland to a family dinner?\n\nJust in case a dramatic revelation led to a spontaneous song and dance sequence!',
#  'explanation': "This joke plays on several common stereotypes and tropes associated with **Bollywood films**:\n\n1.  **Dramatic Revelations:** Bollywood plots are famous for their often over-the-top, emotional, and dramatic twists and turns, especially within family dynamics (long-lost relatives, secret loves, betrayals, etc.).\n2.  **Spontaneous Song and Dance Sequences:** A hallmark of Bollywood is that characters frequently burst into elaborate song and dance numbers to express their emotions, move the plot forward, or simply for entertainment. These sequences often happen in picturesque, exotic locations.\n3.  **Switzerland as a Filming Location:** Switzerland, with its beautiful mountains, lakes, and scenic landscapes, has been a hugely popular and iconic backdrop for countless Bollywood song-and-dance sequences, especially romantic ones, for decades. It's almost a running gag itself how often Bollywood films feature Switzerland.\n\n**The Humor:**\n\nThe humor comes from the absurd juxtaposition and exaggeration:\n\n*   **The Actor's Preparation:** The idea that a Bollywood actor is so ingrained in their craft (or the conventions of Bollywood cinema) that they'd *prepare* for a spontaneous film-like musical number even at a casual, private family dinner is inherently silly.\n*   **Bringing a Map:** Instead of, say, cue cards or a portable speaker, they bring a *map of Switzerland*, implying they're ready to immediately teleport to an iconic Bollywood filming location for their emotional outburst.\n*   **The Everyday vs. The Cinematic:** It highlights the contrast between the mundane reality of a family dinner and the heightened, stylized reality of a Bollywood movie. The actor is treating a potential family argument as if it were a scene from their next big film.\n\nIn essence, the actor is hilariously ready for life to suddenly turn into a full-blown Bollywood movie, complete with an immediate escape route to a classic song-and-dance location!"}

# %%
# Old explanation
print(final_state2['explanation'])
# Out:
# This joke plays on several classic Bollywood tropes:
#
# 1.  **Dramatic Revelations at Family Events:** Bollywood films are famous for their high drama, often involving long-lost relatives, secret love affairs, hidden parentage, or other major family secrets that come to light, usually with shouting, tears, and grand gestures. A family dinner is a perfect setting for such a "dramatic revelation."
#
# 2.  **Spontaneous Song and Dance Sequences:** This is the absolute hallmark of Bollywood cinema. Characters frequently break into elaborate song and dance numbers, seemingly out of nowhere, to express intense emotions, advance the plot, or simply provide a colorful interlude. These sequences are often triggered by a significant emotional event – like a "dramatic revelation."
#
# 3.  **Exotic Filming Locations for Song Sequences:** Many Bollywood song sequences are shot in breathtaking, picturesque international locations, even if the rest of the film is set in India. **Switzerland** is one of the *most famous and beloved* international backdrops for Bollywood song and dance numbers. Its snowy mountains, lush green fields, and charming villages have appeared in countless Hindi films, becoming almost synonymous with romantic song sequences.
#
# **Putting it all together:**
#
# The joke imagines a Bollywood actor, so immersed in the conventions of his craft, that he anticipates a typical cinematic event happening in real life. He's thinking:
#
# *   "Oh no, a family dinner! This is where secrets usually explode!" (Dramatic revelation)
# *   "And when secrets explode, emotions run high, which means... it's time for a song and dance!" (Spontaneous song and dance)
# *   "And where do the best, most beautiful song and dance sequences happen? In Switzerland, of course!"
#
# So, the actor brings a map of Switzerland, "just in case" the dramatic family revelation leads to an immediate need for a picturesque backdrop for an impromptu musical number, à la a typical Bollywood movie. The humor comes from the absurdity of applying these hyper-stylized cinematic conventions to a real-life, mundane family dinner.

# %%
## kept same joke but explanation generated newly(above)
print(final_state2['joke'])
# Out:
# Why did the Bollywood actor bring a map of Switzerland to a family dinner?
#
# Just in case a dramatic revelation led to a spontaneous song and dance sequence!

# %% [markdown]
# ###  Update state
# ```
# We can update state values
# ```

# %%
updated_final_state = joke_and_explain.update_state({"configurable": {'thread_id':"2", 'checkpoint_id': '1f0c5379-a49f-6b12-8000-54b788793a5a', 'checkpoint_ns': ""}}, {'topic': 'Data Science'})

# %%
updated_final_state
# Out:
# {'configurable': {'thread_id': '2',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0c5398-8a7d-6b4f-8001-9075c9b0ba9f'}}

# %%
list(joke_and_explain.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'Data Science'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c5398-8a7d-6b4f-8001-9075c9b0ba9f'}}, metadata={'source': 'update', 'step': 1, 'parents': {}}, created_at='2025-11-19T11:18:54.499515+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c5379-a49f-6b12-8000-54b788793a5a'}}, tasks=(PregelTask(id='387e53cc-688e-d532-a748-1de7fed7a1fd', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={'topic': 'Bollywood', 'joke': 'Why did the Bollywood actor bring a map of Switzerland to a family dinner?\n\nJust in case a dramatic revelation led to a spontaneous song and dance sequence!', 'explanation': "This joke plays on several common stereotypes and tropes associated with **Bollywood films**:\n\n1.  **Dramatic Revelations:** Bollywood plots are famous for their often over-the-top, emotional, and dramatic twists and turns, especially within family dynamics (long-lost relatives, secret loves, betrayals, etc.).\n2.  **Spontaneous Song and Dance Sequences:** A hallmark of Bollywood is that characters frequently burst into elaborate song and dance numbers to express their emotions, move the plot forward, or simply for entertainment. These sequences often happen in picturesque, exotic locations.\n3.  **Switzerland as a Filming Location:** Switzerland, with its beautiful mountains, lakes, and scenic landscapes, has been a hugely popular and iconic backdrop for countless Bollywood song-and-dance sequences, especially romantic ones, for decades. It's almost a running gag itself how often Bollywood films feature Switzerland.\n\n**The Humor:**\n\nThe humor comes from the absurd juxtaposition and exaggeration:\n\n*   **The Actor's Preparation:** The idea that a Bollywood actor is so ingrained in their craft (or the conventions of Bollywood cinema) that they'd *prepare* for a spontaneous film-like musical number even at a casual, private family dinner is inherently silly.\n*   **Bringing a Map:** Instead of, say, cue cards or a portable speaker, they bring a *map of Switzerland*, implying they're ready to immediately teleport to an iconic Bollywood filming location for their emotional outburst.\n*   **The Everyday vs. The Cinematic:** It highlights the contrast between the mundane reality of a family dinner and the heightened, stylized reality of a Bollywood movie. The actor is treating a potential family argument as if it were a scene from their next big film.\n\nIn essence, the actor is hilariously ready for life to suddenly turn into a full-blown Bollywood movie, complete with an immediate escape route to a classic song-and-dance location!"}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c537d-0c56-6af2-8002-48f4e953f7a6'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-11-19T11:06:36.495742+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c537a-1157-6174-8001-b9d6a8373253'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'Bollywood', 'joke': 'Why did the Bollywood actor bring a map of Switzerland to a family dinner?\n\nJust in case a dramatic revelation led to a spontaneous song and dance sequence!', 'explanation': 'This joke plays on several classic Bollywood tropes:\n\n1.  **Dramatic Revelations at Family Events:** Bollywood films are famous for their high drama, often involving long-lost relatives, secret love affairs, hidden parentage, or other major family secrets that come to light, usually with shouting, tears, and grand gestures. A family dinner is a perfect setting for such a "dramatic revelation."\n\n2.  **Spontaneous Song and Dance Sequences:** This is the absolute hallmark of Bollywood cinema. Characters frequently break into elaborate song and dance numbers, seemingly out of nowhere, to express intense emotions, advance the plot, or simply provide a colorful interlude. These sequences are often triggered by a significant emotional event – like a "dramatic revelation."\n\n3.  **Exotic Filming Locations for Song Sequences:** Many Bollywood song sequences are shot in breathtaking, picturesque international locations, even if the rest of the film is set in India. **Switzerland** is one of the *most famous and beloved* international backdrops for Bollywood song and dance numbers. Its snowy mountains, lush green fields, and charming villages have appeared in countless Hindi films, becoming almost synonymous with romantic song sequences.\n\n**Putting it all together:**\n\nThe joke imagines a Bollywood actor, so immersed in the conventions of his craft, that he anticipates a typical cinematic event happening in real life. He\'s thinking:\n\n*   "Oh no, a family dinner! This is where secrets usually explode!" (Dramatic revelation)\n*   "And when secrets explode, emotions run high, which means... it\'s time for a song and dance!" (Spontaneous song and dance)\n*   "And where do the best, most beautiful song and dance sequences happen? In Switzerland, of course!"\n\nSo, the actor brings a map of Switzerland, "just in case" the dramatic family revelation leads to an immediate need for a picturesque backdrop for an impromptu musical number, à la a typical Bollywood movie. The humor comes from the absurdity of applying these hyper-stylized cinematic conventions to a real-life, mundane family dinner.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c537a-6533-660e-8002-d7aeef8d1ff8'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-11-19T11:05:25.282971+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c537a-1157-6174-8001-b9d6a8373253'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'Bollywood', 'joke': 'Why did the Bollywood actor bring a map of Switzerland to a family dinner?\n\nJust in case a dramatic revelation led to a spontaneous song and dance sequence!'}, next=('get_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c537a-1157-6174-8001-b9d6a8373253'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-11-19T11:05:16.489560+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c5379-a49f-6b12-8000-54b788793a5a'}}, tasks=(PregelTask(id='15509699-129a-60c0-84fd-e9d567725421', name='get_explanation', path=('__pregel_pull', 'get_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke plays on several classic Bollywood tropes:\n\n1.  **Dramatic Revelations at Family Events:** Bollywood films are famous for their high drama, often involving long-lost relatives, secret love affairs, hidden parentage, or other major family secrets that come to light, usually with shouting, tears, and grand gestures. A family dinner is a perfect setting for such a "dramatic revelation."\n\n2.  **Spontaneous Song and Dance Sequences:** This is the absolute hallmark of Bollywood cinema. Characters frequently break into elaborate song and dance numbers, seemingly out of nowhere, to express intense emotions, advance the plot, or simply provide a colorful interlude. These sequences are often triggered by a significant emotional event – like a "dramatic revelation."\n\n3.  **Exotic Filming Locations for Song Sequences:** Many Bollywood song sequences are shot in breathtaking, picturesque international locations, even if the rest of the film is set in India. **Switzerland** is one of the *most famous and beloved* international backdrops for Bollywood song and dance numbers. Its snowy mountains, lush green fields, and charming villages have appeared in countless Hindi films, becoming almost synonymous with romantic song sequences.\n\n**Putting it all together:**\n\nThe joke imagines a Bollywood actor, so immersed in the conventions of his craft, that he anticipates a typical cinematic event happening in real life. He\'s thinking:\n\n*   "Oh no, a family dinner! This is where secrets usually explode!" (Dramatic revelation)\n*   "And when secrets explode, emotions run high, which means... it\'s time for a song and dance!" (Spontaneous song and dance)\n*   "And where do the best, most beautiful song and dance sequences happen? In Switzerland, of course!"\n\nSo, the actor brings a map of Switzerland, "just in case" the dramatic family revelation leads to an immediate need for a picturesque backdrop for an impromptu musical number, à la a typical Bollywood movie. The humor comes from the absurdity of applying these hyper-stylized cinematic conventions to a real-life, mundane family dinner.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'Bollywood'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c5379-a49f-6b12-8000-54b788793a5a'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-11-19T11:05:05.089819+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c5379-a49d-639e-bfff-6fd0d67c60ac'}}, tasks=(PregelTask(id='e9897d55-3d35-2af5-1ec9-c29b73f15d59', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the Bollywood actor bring a map of Switzerland to a family dinner?\n\nJust in case a dramatic revelation led to a spontaneous song and dance sequence!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c5379-a49d-639e-bfff-6fd0d67c60ac'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-11-19T11:05:05.088809+00:00', parent_config=None, tasks=(PregelTask(id='99fab488-acac-f1be-4093-e6bae600717d', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'Bollywood'}),), interrupts=())]

# %%
updated_final_state_gen = joke_and_explain.invoke(None, {"configurable": {'thread_id':"2", 'checkpoint_id': '1f0c5398-8a7d-6b4f-8001-9075c9b0ba9f'}})

# %%
list(joke_and_explain.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'Data Science', 'joke': 'Here are a few humorous jokes about data science:\n\n1.  Why did the data scientist break up with their dataset?\n    **It had too many missing values and was constantly trying to normalize their relationship!**\n\n2.  What do you call a data scientist who believes correlation implies causation?\n    **Naive Bayes!**\n\n3.  A data scientist, a statistician, and a business analyst walk into a bar.\n    The business analyst says, "We need actionable insights!"\n    The statistician says, "We need to account for confounding variables!"\n    The data scientist sighs and says, **"I just need to figure out which column is the actual timestamp."**\n\n4.  Why did the data scientist get kicked out of the garden party?\n    **They kept trying to prune the rose bushes for overfitting.**\n\n5.  Manager asks the data scientist: "Can you predict next quarter\'s sales?"\n    Data Scientist: "Yes! With 99% accuracy... of what happened last quarter."', 'explanation': 'These jokes play on common challenges, frustrations, and inside baseball terminology within the field of data science.\n\nHere\'s a breakdown of each:\n\n1.  **Why did the data scientist break up with their dataset?**\n    **It had too many missing values and was constantly trying to normalize their relationship!**\n    *   **Data Science Context:**\n        *   **Missing values:** A very common and frustrating problem in real-world datasets where some data points are simply absent. Data scientists spend a lot of time cleaning and handling these.\n        *   **Normalize:** A data preprocessing technique used to scale numerical data to a standard range (e.g., between 0 and 1) so that features with larger values don\'t disproportionately influence machine learning algorithms.\n    *   **The Joke:** It anthropomorphizes the dataset, applying technical data cleaning and preprocessing terms to the emotional struggles of a human relationship. "Missing values" sounds like a lack of emotional presence, and "constantly trying to normalize their relationship" sounds like one partner always trying to make things "normal" or conform, which can be exhausting. The humor comes from the data scientist seeing their relationship problems through the lens of their professional challenges.\n\n2.  **What do you call a data scientist who believes correlation implies causation?**\n    **Naive Bayes!**\n    *   **Data Science Context:**\n        *   **Correlation implies causation:** This is a fundamental statistical fallacy. Just because two things move together (correlate) doesn\'t mean one causes the other. Anyone who believes this is generally considered "naive."\n        *   **Naive Bayes:** A classification algorithm (a type of machine learning model) that is called "naive" because it makes a *simplifying assumption* that all features are conditionally independent of each other given the class variable. This assumption is rarely true in real-world data, but the algorithm still often performs surprisingly well.\n    *   **The Joke:** It\'s a pun! Someone who incorrectly assumes correlation implies causation is "naive" in a general sense. The joke connects this general "naiveté" to a specific data science algorithm that literally has "Naive" in its name due to its own simplifying (and often unrealistic) assumptions about data independence.\n\n3.  **A data scientist, a statistician, and a business analyst walk into a bar.**\n    **The business analyst says, "We need actionable insights!"**\n    **The statistician says, "We need to account for confounding variables!"**\n    **The data scientist sighs and says, "I just need to figure out which column is the actual timestamp."**\n    *   **Data Science Context:**\n        *   **Actionable insights (Business Analyst):** This is typically what a business analyst aims for – clear, useful information that can lead to business decisions.\n        *   **Confounding variables (Statistician):** A core co ...
#  StateSnapshot(values={'topic': 'Data Science', 'joke': 'Here are a few humorous jokes about data science:\n\n1.  Why did the data scientist break up with their dataset?\n    **It had too many missing values and was constantly trying to normalize their relationship!**\n\n2.  What do you call a data scientist who believes correlation implies causation?\n    **Naive Bayes!**\n\n3.  A data scientist, a statistician, and a business analyst walk into a bar.\n    The business analyst says, "We need actionable insights!"\n    The statistician says, "We need to account for confounding variables!"\n    The data scientist sighs and says, **"I just need to figure out which column is the actual timestamp."**\n\n4.  Why did the data scientist get kicked out of the garden party?\n    **They kept trying to prune the rose bushes for overfitting.**\n\n5.  Manager asks the data scientist: "Can you predict next quarter\'s sales?"\n    Data Scientist: "Yes! With 99% accuracy... of what happened last quarter."'}, next=('get_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c53a5-9809-6257-8002-e7adb46dbef6'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-11-19T11:24:44.885871+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c5398-8a7d-6b4f-8001-9075c9b0ba9f'}}, tasks=(PregelTask(id='55c70702-df99-ce42-f416-655538e33f0a', name='get_explanation', path=('__pregel_pull', 'get_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'These jokes play on common challenges, frustrations, and inside baseball terminology within the field of data science.\n\nHere\'s a breakdown of each:\n\n1.  **Why did the data scientist break up with their dataset?**\n    **It had too many missing values and was constantly trying to normalize their relationship!**\n    *   **Data Science Context:**\n        *   **Missing values:** A very common and frustrating problem in real-world datasets where some data points are simply absent. Data scientists spend a lot of time cleaning and handling these.\n        *   **Normalize:** A data preprocessing technique used to scale numerical data to a standard range (e.g., between 0 and 1) so that features with larger values don\'t disproportionately influence machine learning algorithms.\n    *   **The Joke:** It anthropomorphizes the dataset, applying technical data cleaning and preprocessing terms to the emotional struggles of a human relationship. "Missing values" sounds like a lack of emotional presence, and "constantly trying to normalize their relationship" sounds like one partner always trying to make things "normal" or conform, which can be exhausting. The humor comes from the data scientist seeing their relationship problems through the lens of their professional challenges.\n\n2.  **What do you call a data scientist who believes correlation implies causation?**\n    **Naive Bayes!**\n    *   **Data Science Context:**\n        *   **Correlation implies causation:** This is a fundamental statistical fallacy. Just because two things move together (correlate) doesn\'t mean one causes the other. Anyone who believes this is generally considered "naive."\n        *   **Naive Bayes:** A classification algorithm (a type of machine learning model) that is called "naive" because it makes a *simplifying assumption* that all features are conditionally independent of each other given the class variable. This assumption is rarely true in real-world data, but the algorithm still often performs surprisingly well.\n    *   **The Joke:** It\'s a pun! Someone who incorrectly assumes correlation implies causation is "naive" in a general sense. The joke connects this general "naiveté" to a specific data science algorithm that literally has "Naive" in its name due to its own simplifying (and often unrealistic) assumptions about data independence.\n\n3.  **A data scientist, a statistician, and a busines ...
#  StateSnapshot(values={'topic': 'Bollywood', 'joke': 'Why did the Bollywood director get kicked out of the library?\n\nHe kept trying to add a 15-minute song-and-dance number in the middle of a serious monologue!', 'explanation': 'This joke plays on the strong, contrasting stereotypes of two very different environments:\n\n1.  **Bollywood Films:**\n    *   **Characteristic:** They are famous for frequently incorporating elaborate, often lengthy (sometimes 10-15 minutes or more) song-and-dance numbers. These musical sequences often appear in the middle of dramatic or serious scenes, sometimes interrupting the narrative flow, or serving as a highly emotional expression of a character\'s feelings that isn\'t conveyed through dialogue alone.\n    *   **Feel:** Grand, loud, colorful, expressive, dramatic, high-energy.\n\n2.  **A Library:**\n    *   **Characteristic:** Libraries are places of quiet, study, reading, and contemplation. There\'s an expectation of silence and decorum. Loud disruptions are strictly forbidden.\n    *   **Feel:** Calm, quiet, serious, respectful, focused.\n\n**The Humor:**\n\nThe humor comes from the **absurd clash** between these two worlds:\n\n*   The Bollywood director, acting completely in character with the conventions of his industry, tries to introduce a signature Bollywood element (a 15-minute, loud, energetic song-and-dance number) into the most inappropriate setting imaginable: a silent library.\n*   The "serious monologue" further emphasizes the quiet, intense, and focused nature of what *should* be happening in a library, making the proposed interruption even more outrageous.\n*   "Getting kicked out" is the entirely logical (and comical) consequence of such disruptive behavior in a place that values quiet above all else.\n\nIt\'s funny because it takes a well-known cultural trope (Bollywood\'s love for musical numbers) and exaggerates its application into a completely incompatible context, highlighting the ridiculousness of the situation.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c53a3-0f9e-6dfd-8002-c7da30eb5357'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-11-19T11:23:36.894617+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c53a2-c466-6db3-8001-fe5c0985252f'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'Bollywood', 'joke': 'Why did the Bollywood director get kicked out of the library?\n\nHe kept trying to add a 15-minute song-and-dance number in the middle of a serious monologue!'}, next=('get_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c53a2-c466-6db3-8001-fe5c0985252f'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-11-19T11:23:29.007352+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c5379-a49f-6b12-8000-54b788793a5a'}}, tasks=(PregelTask(id='0a807c26-df54-6d63-04f7-eba535a6cd4d', name='get_explanation', path=('__pregel_pull', 'get_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke plays on the strong, contrasting stereotypes of two very different environments:\n\n1.  **Bollywood Films:**\n    *   **Characteristic:** They are famous for frequently incorporating elaborate, often lengthy (sometimes 10-15 minutes or more) song-and-dance numbers. These musical sequences often appear in the middle of dramatic or serious scenes, sometimes interrupting the narrative flow, or serving as a highly emotional expression of a character\'s feelings that isn\'t conveyed through dialogue alone.\n    *   **Feel:** Grand, loud, colorful, expressive, dramatic, high-energy.\n\n2.  **A Library:**\n    *   **Characteristic:** Libraries are places of quiet, study, reading, and contemplation. There\'s an expectation of silence and decorum. Loud disruptions are strictly forbidden.\n    *   **Feel:** Calm, quiet, serious, respectful, focused.\n\n**The Humor:**\n\nThe humor comes from the **absurd clash** between these two worlds:\n\n*   The Bollywood director, acting completely in character with the conventions of his industry, tries to introduce a signature Bollywood element (a 15-minute, loud, energetic song-and-dance number) into the most inappropriate setting imaginable: a silent library.\n*   The "serious monologue" further emphasizes the quiet, intense, and focused nature of what *should* be happening in a library, making the proposed interruption even more outrageous.\n*   "Getting kicked out" is the entirely logical (and comical) consequence of such disruptive behavior in a place that values quiet above all else.\n\nIt\'s funny because it takes a well-known cultural trope (Bollywood\'s love for musical numbers) and exaggerates its application into a completely incompatible context, highlighting the ridiculousness of the situation.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'Data Science'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c5398-8a7d-6b4f-8001-9075c9b0ba9f'}}, metadata={'source': 'update', 'step': 1, 'parents': {}}, created_at='2025-11-19T11:18:54.499515+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c5379-a49f-6b12-8000-54b788793a5a'}}, tasks=(PregelTask(id='387e53cc-688e-d532-a748-1de7fed7a1fd', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Here are a few humorous jokes about data science:\n\n1.  Why did the data scientist break up with their dataset?\n    **It had too many missing values and was constantly trying to normalize their relationship!**\n\n2.  What do you call a data scientist who believes correlation implies causation?\n    **Naive Bayes!**\n\n3.  A data scientist, a statistician, and a business analyst walk into a bar.\n    The business analyst says, "We need actionable insights!"\n    The statistician says, "We need to account for confounding variables!"\n    The data scientist sighs and says, **"I just need to figure out which column is the actual timestamp."**\n\n4.  Why did the data scientist get kicked out of the garden party?\n    **They kept trying to prune the rose bushes for overfitting.**\n\n5.  Manager asks the data scientist: "Can you predict next quarter\'s sales?"\n    Data Scientist: "Yes! With 99% accuracy... of what happened last quarter."'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'Bollywood', 'joke': 'Why did the Bollywood actor bring a map of Switzerland to a family dinner?\n\nJust in case a dramatic revelation led to a spontaneous song and dance sequence!', 'explanation': "This joke plays on several common stereotypes and tropes associated with **Bollywood films**:\n\n1.  **Dramatic Revelations:** Bollywood plots are famous for their often over-the-top, emotional, and dramatic twists and turns, especially within family dynamics (long-lost relatives, secret loves, betrayals, etc.).\n2.  **Spontaneous Song and Dance Sequences:** A hallmark of Bollywood is that characters frequently burst into elaborate song and dance numbers to express their emotions, move the plot forward, or simply for entertainment. These sequences often happen in picturesque, exotic locations.\n3.  **Switzerland as a Filming Location:** Switzerland, with its beautiful mountains, lakes, and scenic landscapes, has been a hugely popular and iconic backdrop for countless Bollywood song-and-dance sequences, especially romantic ones, for decades. It's almost a running gag itself how often Bollywood films feature Switzerland.\n\n**The Humor:**\n\nThe humor comes from the absurd juxtaposition and exaggeration:\n\n*   **The Actor's Preparation:** The idea that a Bollywood actor is so ingrained in their craft (or the conventions of Bollywood cinema) that they'd *prepare* for a spontaneous film-like musical number even at a casual, private family dinner is inherently silly.\n*   **Bringing a Map:** Instead of, say, cue cards or a portable speaker, they bring a *map of Switzerland*, implying they're ready to immediately teleport to an iconic Bollywood filming location for their emotional outburst.\n*   **The Everyday vs. The Cinematic:** It highlights the contrast between the mundane reality of a family dinner and the heightened, stylized reality of a Bollywood movie. The actor is treating a potential family argument as if it were a scene from their next big film.\n\nIn essence, the actor is hilariously ready for life to suddenly turn into a full-blown Bollywood movie, complete with an immediate escape route to a classic song-and-dance location!"}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c537d-0c56-6af2-8002-48f4e953f7a6'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-11-19T11:06:36.495742+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c537a-1157-6174-8001-b9d6a8373253'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'Bollywood', 'joke': 'Why did the Bollywood actor bring a map of Switzerland to a family dinner?\n\nJust in case a dramatic revelation led to a spontaneous song and dance sequence!', 'explanation': 'This joke plays on several classic Bollywood tropes:\n\n1.  **Dramatic Revelations at Family Events:** Bollywood films are famous for their high drama, often involving long-lost relatives, secret love affairs, hidden parentage, or other major family secrets that come to light, usually with shouting, tears, and grand gestures. A family dinner is a perfect setting for such a "dramatic revelation."\n\n2.  **Spontaneous Song and Dance Sequences:** This is the absolute hallmark of Bollywood cinema. Characters frequently break into elaborate song and dance numbers, seemingly out of nowhere, to express intense emotions, advance the plot, or simply provide a colorful interlude. These sequences are often triggered by a significant emotional event – like a "dramatic revelation."\n\n3.  **Exotic Filming Locations for Song Sequences:** Many Bollywood song sequences are shot in breathtaking, picturesque international locations, even if the rest of the film is set in India. **Switzerland** is one of the *most famous and beloved* international backdrops for Bollywood song and dance numbers. Its snowy mountains, lush green fields, and charming villages have appeared in countless Hindi films, becoming almost synonymous with romantic song sequences.\n\n**Putting it all together:**\n\nThe joke imagines a Bollywood actor, so immersed in the conventions of his craft, that he anticipates a typical cinematic event happening in real life. He\'s thinking:\n\n*   "Oh no, a family dinner! This is where secrets usually explode!" (Dramatic revelation)\n*   "And when secrets explode, emotions run high, which means... it\'s time for a song and dance!" (Spontaneous song and dance)\n*   "And where do the best, most beautiful song and dance sequences happen? In Switzerland, of course!"\n\nSo, the actor brings a map of Switzerland, "just in case" the dramatic family revelation leads to an immediate need for a picturesque backdrop for an impromptu musical number, à la a typical Bollywood movie. The humor comes from the absurdity of applying these hyper-stylized cinematic conventions to a real-life, mundane family dinner.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c537a-6533-660e-8002-d7aeef8d1ff8'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-11-19T11:05:25.282971+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c537a-1157-6174-8001-b9d6a8373253'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'Bollywood', 'joke': 'Why did the Bollywood actor bring a map of Switzerland to a family dinner?\n\nJust in case a dramatic revelation led to a spontaneous song and dance sequence!'}, next=('get_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c537a-1157-6174-8001-b9d6a8373253'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-11-19T11:05:16.489560+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c5379-a49f-6b12-8000-54b788793a5a'}}, tasks=(PregelTask(id='15509699-129a-60c0-84fd-e9d567725421', name='get_explanation', path=('__pregel_pull', 'get_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke plays on several classic Bollywood tropes:\n\n1.  **Dramatic Revelations at Family Events:** Bollywood films are famous for their high drama, often involving long-lost relatives, secret love affairs, hidden parentage, or other major family secrets that come to light, usually with shouting, tears, and grand gestures. A family dinner is a perfect setting for such a "dramatic revelation."\n\n2.  **Spontaneous Song and Dance Sequences:** This is the absolute hallmark of Bollywood cinema. Characters frequently break into elaborate song and dance numbers, seemingly out of nowhere, to express intense emotions, advance the plot, or simply provide a colorful interlude. These sequences are often triggered by a significant emotional event – like a "dramatic revelation."\n\n3.  **Exotic Filming Locations for Song Sequences:** Many Bollywood song sequences are shot in breathtaking, picturesque international locations, even if the rest of the film is set in India. **Switzerland** is one of the *most famous and beloved* international backdrops for Bollywood song and dance numbers. Its snowy mountains, lush green fields, and charming villages have appeared in countless Hindi films, becoming almost synonymous with romantic song sequences.\n\n**Putting it all together:**\n\nThe joke imagines a Bollywood actor, so immersed in the conventions of his craft, that he anticipates a typical cinematic event happening in real life. He\'s thinking:\n\n*   "Oh no, a family dinner! This is where secrets usually explode!" (Dramatic revelation)\n*   "And when secrets explode, emotions run high, which means... it\'s time for a song and dance!" (Spontaneous song and dance)\n*   "And where do the best, most beautiful song and dance sequences happen? In Switzerland, of course!"\n\nSo, the actor brings a map of Switzerland, "just in case" the dramatic family revelation leads to an immediate need for a picturesque backdrop for an impromptu musical number, à la a typical Bollywood movie. The humor comes from the absurdity of applying these hyper-stylized cinematic conventions to a real-life, mundane family dinner.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'Bollywood'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c5379-a49f-6b12-8000-54b788793a5a'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-11-19T11:05:05.089819+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c5379-a49d-639e-bfff-6fd0d67c60ac'}}, tasks=(PregelTask(id='e9897d55-3d35-2af5-1ec9-c29b73f15d59', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the Bollywood actor bring a map of Switzerland to a family dinner?\n\nJust in case a dramatic revelation led to a spontaneous song and dance sequence!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0c5379-a49d-639e-bfff-6fd0d67c60ac'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-11-19T11:05:05.088809+00:00', parent_config=None, tasks=(PregelTask(id='99fab488-acac-f1be-4093-e6bae600717d', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'Bollywood'}),), interrupts=())]

# %%
# next step --> backend- langgraph and frontend- Streamlit
